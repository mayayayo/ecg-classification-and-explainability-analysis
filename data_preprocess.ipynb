# %% [markdown]
# # Pre-processing of ECG data for arrythmia detection

# %%
# !pip install wfdb
# !pip install biosppy
# Out:
# Requirement already satisfied: wfdb in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (4.3.0)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (3.13.2)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (2025.10.0)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (3.10.6)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (2.2.6)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (2.3.3)
# Requirement already satisfied: requests>=2.8.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (2.32.5)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (1.16.2)
# Requirement already satisfied: soundfile>=0.10.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10.11->wfdb) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib>=3.2.2->wfdb) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib>=3.2.2->wfdb) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib>=3.2.2->wfdb) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib>=3.2.2->wfdb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\new\appdata\roaming\python\python313\site-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib>=3.2.2->wfdb) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib>=3.2.2->wfdb) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\new\appdata\roaming\python\python313\site-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\new\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from requests>=2.8.1->wfdb) (2025.11.12)
# Requirement already satisfied: cffi>=1.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Requirement already satisfied: biosppy in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (2.2.4)
# Requirement already satisfied: bidict in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (0.23.1)
# Requirement already satisfied: h5py in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (3.15.1)
# Requirement already satisfied: matplotlib in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (3.10.6)
# Requirement already satisfied: numpy in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (2.2.6)
# Requirement already satisfied: scikit-learn in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (1.7.2)
# Requirement already satisfied: scipy in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (1.16.2)
# Requirement already satisfied: shortuuid in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (1.0.13)
# Requirement already satisfied: six in c:\users\new\appdata\roaming\python\python313\site-packages (from biosppy) (1.17.0)
# Requirement already satisfied: joblib in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (1.5.2)
# Requirement already satisfied: opencv-python in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (4.12.0.88)
# Requirement already satisfied: pywavelets in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (1.9.0)
# Requirement already satisfied: mock in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from biosppy) (5.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib->biosppy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib->biosppy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib->biosppy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib->biosppy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\new\appdata\roaming\python\python313\site-packages (from matplotlib->biosppy) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib->biosppy) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from matplotlib->biosppy) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\new\appdata\roaming\python\python313\site-packages (from matplotlib->biosppy) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\new\anaconda3\envs\mayabee\lib\site-packages (from scikit-learn->biosppy) (3.6.0)

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import wfdb as wf
import glob
from biosppy.signals import ecg
from wfdb import processing
import scipy
from scipy import *
from os import path

# %% [markdown]
# __Download MIT-BIH Dataset:__
# 1.	Download the zip file with raw data from: https://physionet.org/content/mitdb/1.0.0/
# 2.	Store data into a folder called ‘mitbih’.
# 3.	Access the folder from your notebook.
# 4.	Pre-process the data into a csv file to be used for your models.

# %% [markdown]
# __Data Preprocessing:__
#
# * This data has been pre-annotated and labelled by cardiologists.
# * These different annotations refer to various normal and abnormal ECG signals which represent different types of arrhythmia.
# * The dataset consists of ECG signals of various classes, but the eight classes used for this investigation are ’N’, ’L’, ’R’, ’V’, ’A’, ’F’, ’f’, ’/’.
# * The table shows the description and numerical identification values assigned to these classes.

# %% [markdown]
# __Extract data from the raw MIT-BIH files:__
#
# * Each patient record included a complete set of heartbeats, so each individual beat was extracted from all the records.
# * This is done by matching the R-peaks of the ECG with their respective annotation class and appending the class’ numerical value at the end of the beat.
# * To make every beat contain equal amount of data points, the R-peaks were centered and equal amount of datapoints were selected on both sides of the peak.
# * This allowed us to maintain consistency for each beat. To avoid irregular amplitudes between signals.

# %% [markdown]
# __Generate the classifications based on the annotations:__
#
# * 0.0 = undetermined
# * 1.0 = normal
# * 2.0 = LBBBB
# * 3.0 = RBBBB
# * 4.0 = Premature Ventricular contraction
# * 5.0 = Atrial Premature beat
# * 6.0 = Fusion ventricular normal beat
# * 7.0 = Fusion of paced and normal beat
# * 8.0 = paced beat

# %%
def extract_data():
    data_files = glob.glob('./mitbih/*.atr')
    data_files = [i[:-4] for i in data_files]
    data_files.sort()
    return data_files

length = 275
records = extract_data()
print('Total files: ', len(records))

good_beats = ['N','L','R','B','A','a','J','S','V','r',
             'F','e','j','n','E','/','f','Q','?']

for file_path in records:
    file_pathpts = file_path.split('/')
    fn = file_pathpts[-1]
    print('Loading file:', file_path)

    # Read in the data
    if path.exists(file_path+".hea"):
        record = wf.rdsamp(file_path)
        annotation = wf.rdann(file_path, 'atr')

        # Print some meta informations
        print('    Sampling frequency used for this record:', record[1].get('fs'))
        print('    Shape of loaded data array:', record[0].shape)
        print('    Number of loaded annotations:', len(annotation.num))

        # Get the ECG values from the file.
        data = record[0].transpose()

        clas = np.array(annotation.symbol)
        rate = np.zeros_like(clas, dtype='float')
        for clasid, clasval in enumerate(clas):
            if (clasval == 'N'):
                rate[clasid] = 1.0 # Normal
            elif (clasval == 'L'):
                rate[clasid] = 2.0 # LBBBB
            elif (clasval == 'R'):
                rate[clasid] = 3.0 # RBBBB
            elif (clasval == 'V'):
                rate[clasid] = 4.0 # Premature Ventricular contraction
            elif (clasval == 'A'):
                rate[clasid] = 5.0 # Atrial Premature beat
            elif (clasval == 'F'):
                rate[clasid] = 6.0 # Fusion ventricular normal beat
            elif (clasval == 'f'):
                rate[clasid] = 7.0 # Fusion of paced and normal beat
            elif (clasval == '/'):
                rate[clasid] = 8.0 # paced beat
            
        rates = np.zeros_like(data[0], dtype='float')
        rates[annotation.sample] = rate

        indices = np.arange(data[0].size, dtype='int')

        # Manipulate both channels
        for channelid, channel in enumerate(data):
            chname = record[1].get('sig_name')[channelid]
            print('    ECG channel type:', chname)

            # Find rpeaks in the ECG data. Most should match with
            # the annotations.
            out = ecg.ecg(signal=channel, sampling_rate=360, show=False)

            # Split into individual heartbeats. For each heartbeat
            # record, append classification.

            beats = []
            for ind, ind_val in enumerate(out['rpeaks']):

                start,end = ind_val-length//2, ind_val+length//2
                if start < 0:
                    start = 0
                diff = length - len(channel[start:end])
                if diff > 0:
                    padding = np.zeros(diff, dtype='float')
                    padded_channel = np.append(padding, channel[start:end])
                    beats.append(padded_channel)
                else:
                    beats.append(channel[start:end])

                # Get the classification value that is on
                # or near the position of the rpeak index.
                from_ind = 0 if ind_val < 10 else ind_val - 10
                to_ind = ind_val + 10
                clasval = rates[from_ind:to_ind].max()

                # Standardize the data
                beats[ind] = ((beats[ind] - np.mean(beats[ind])) / np.std(beats[ind]))

                # Append the classification to the beat data.
                beats[ind] = np.append(beats[ind], clasval)

                # Append the record number to the beat data.
                beats[ind] = np.append(beats[ind], fn[-3:])

            # Save to CSV file.
            savedata = np.array(beats[:], dtype=np.float64)
            outfn = './'+fn+'_'+chname+'.csv'
            print('Generating ', outfn)
            with open(outfn, "wb") as fin:
                np.savetxt(fin, savedata, delimiter=",", fmt='%f')
    else:
        print('    ECG '+file_path+' not complete, skipping')
# Out:
# Total files:  49
# Loading file: ./mitbih\100
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2274
#     ECG channel type: MLII
# Generating  ./mitbih\100_MLII.csv
#     ECG channel type: V5
# Generating  ./mitbih\100_V5.csv
# Loading file: ./mitbih\101
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1874
#     ECG channel type: MLII
# Generating  ./mitbih\101_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\101_V1.csv
# Loading file: ./mitbih\102
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2192
#     ECG channel type: V5
# Generating  ./mitbih\102_V5.csv
#     ECG channel type: V2
# Generating  ./mitbih\102_V2.csv
# Loading file: ./mitbih\102-0
#     ECG ./mitbih\102-0 not complete, skipping
# Loading file: ./mitbih\103
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2091
#     ECG channel type: MLII
# Generating  ./mitbih\103_MLII.csv
#     ECG channel type: V2
# Generating  ./mitbih\103_V2.csv
# Loading file: ./mitbih\104
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2311
#     ECG channel type: V5
# Generating  ./mitbih\104_V5.csv
#     ECG channel type: V2
# Generating  ./mitbih\104_V2.csv
# Loading file: ./mitbih\105
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2691
#     ECG channel type: MLII
# Generating  ./mitbih\105_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\105_V1.csv
# Loading file: ./mitbih\106
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2098
#     ECG channel type: MLII
# Generating  ./mitbih\106_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\106_V1.csv
# Loading file: ./mitbih\107
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2140
#     ECG channel type: MLII
# Generating  ./mitbih\107_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\107_V1.csv
# Loading file: ./mitbih\108
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1824
#     ECG channel type: MLII
# Generating  ./mitbih\108_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\108_V1.csv
# Loading file: ./mitbih\109
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2535
#     ECG channel type: MLII
# Generating  ./mitbih\109_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\109_V1.csv
# Loading file: ./mitbih\111
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2133
#     ECG channel type: MLII
# Generating  ./mitbih\111_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\111_V1.csv
# Loading file: ./mitbih\112
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2550
#     ECG channel type: MLII
# Generating  ./mitbih\112_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\112_V1.csv
# Loading file: ./mitbih\113
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1796
#     ECG channel type: MLII
# Generating  ./mitbih\113_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\113_V1.csv
# Loading file: ./mitbih\114
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1890
#     ECG channel type: V5
# Generating  ./mitbih\114_V5.csv
#     ECG channel type: MLII
# Generating  ./mitbih\114_MLII.csv
# Loading file: ./mitbih\115
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1962
#     ECG channel type: MLII
# Generating  ./mitbih\115_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\115_V1.csv
# Loading file: ./mitbih\116
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2421
#     ECG channel type: MLII
# Generating  ./mitbih\116_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\116_V1.csv
# Loading file: ./mitbih\117
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1539
#     ECG channel type: MLII
# Generating  ./mitbih\117_MLII.csv
#     ECG channel type: V2
# Generating  ./mitbih\117_V2.csv
# Loading file: ./mitbih\118
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2301
#     ECG channel type: MLII
# Generating  ./mitbih\118_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\118_V1.csv
# Loading file: ./mitbih\119
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2094
#     ECG channel type: MLII
# Generating  ./mitbih\119_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\119_V1.csv
# Loading file: ./mitbih\121
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1876
#     ECG channel type: MLII
# Generating  ./mitbih\121_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\121_V1.csv
# Loading file: ./mitbih\122
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2479
#     ECG channel type: MLII
# Generating  ./mitbih\122_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\122_V1.csv
# Loading file: ./mitbih\123
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1519
#     ECG channel type: MLII
# Generating  ./mitbih\123_MLII.csv
#     ECG channel type: V5
# Generating  ./mitbih\123_V5.csv
# Loading file: ./mitbih\124
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1634
#     ECG channel type: MLII
# Generating  ./mitbih\124_MLII.csv
#     ECG channel type: V4
# Generating  ./mitbih\124_V4.csv
# Loading file: ./mitbih\200
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2792
#     ECG channel type: MLII
# Generating  ./mitbih\200_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\200_V1.csv
# Loading file: ./mitbih\201
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2039
#     ECG channel type: MLII
# Generating  ./mitbih\201_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\201_V1.csv
# Loading file: ./mitbih\202
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2146
#     ECG channel type: MLII
# Generating  ./mitbih\202_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\202_V1.csv
# Loading file: ./mitbih\203
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3108
#     ECG channel type: MLII
# Generating  ./mitbih\203_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\203_V1.csv
# Loading file: ./mitbih\205
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2672
#     ECG channel type: MLII
# Generating  ./mitbih\205_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\205_V1.csv
# Loading file: ./mitbih\207
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2385
#     ECG channel type: MLII
# Generating  ./mitbih\207_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\207_V1.csv
# Loading file: ./mitbih\208
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3040
#     ECG channel type: MLII
# Generating  ./mitbih\208_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\208_V1.csv
# Loading file: ./mitbih\209
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3052
#     ECG channel type: MLII
# Generating  ./mitbih\209_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\209_V1.csv
# Loading file: ./mitbih\210
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2685
#     ECG channel type: MLII
# Generating  ./mitbih\210_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\210_V1.csv
# Loading file: ./mitbih\212
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2763
#     ECG channel type: MLII
# Generating  ./mitbih\212_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\212_V1.csv
# Loading file: ./mitbih\213
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3294
#     ECG channel type: MLII
# Generating  ./mitbih\213_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\213_V1.csv
# Loading file: ./mitbih\214
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2297
#     ECG channel type: MLII
# Generating  ./mitbih\214_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\214_V1.csv
# Loading file: ./mitbih\215
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3400
#     ECG channel type: MLII
# Generating  ./mitbih\215_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\215_V1.csv
# Loading file: ./mitbih\217
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2280
#     ECG channel type: MLII
# Generating  ./mitbih\217_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\217_V1.csv
# Loading file: ./mitbih\219
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2312
#     ECG channel type: MLII
# Generating  ./mitbih\219_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\219_V1.csv
# Loading file: ./mitbih\220
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2069
#     ECG channel type: MLII
# Generating  ./mitbih\220_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\220_V1.csv
# Loading file: ./mitbih\221
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2462
#     ECG channel type: MLII
# Generating  ./mitbih\221_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\221_V1.csv
# Loading file: ./mitbih\222
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2634
#     ECG channel type: MLII
# Generating  ./mitbih\222_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\222_V1.csv
# Loading file: ./mitbih\223
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2643
#     ECG channel type: MLII
# Generating  ./mitbih\223_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\223_V1.csv
# Loading file: ./mitbih\228
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2141
#     ECG channel type: MLII
# Generating  ./mitbih\228_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\228_V1.csv
# Loading file: ./mitbih\230
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2466
#     ECG channel type: MLII
# Generating  ./mitbih\230_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\230_V1.csv
# Loading file: ./mitbih\231
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2011
#     ECG channel type: MLII
# Generating  ./mitbih\231_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\231_V1.csv
# Loading file: ./mitbih\232
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1816
#     ECG channel type: MLII
# Generating  ./mitbih\232_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\232_V1.csv
# Loading file: ./mitbih\233
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3152
#     ECG channel type: MLII
# Generating  ./mitbih\233_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\233_V1.csv
# Loading file: ./mitbih\234
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2764
#     ECG channel type: MLII
# Generating  ./mitbih\234_MLII.csv
#     ECG channel type: V1
# Generating  ./mitbih\234_V1.csv

# %%
fig, ax = plt.subplots(2, 1, figsize = (15, 6))
ax[0].plot(data[0, 0:2000])
ax[0].set_ylabel('MLII/mV')
ax[1].plot(data[1, 0:2000])
ax[1].set_ylabel('V5/mV')
ax[1].set_xlabel('time/sample')
ax[0].set_title('Record 234')
fig.savefig('ecg_data_unpreprocessed.jpg', dpi = 400)

# %%
# Combine all the pre-processed data:
new_len = 277
alldata = np.empty(shape=[0, new_len])
all_csv = glob.glob('./mitbih/*.csv')
for j in all_csv:
    csvrows = np.loadtxt(j, delimiter=',')
    alldata = np.append(alldata, csvrows, axis=0)
print(alldata.shape)
# Out:
# (215114, 277)

# %%
# Visualize the pre-processed data: 
fig, ax = plt.subplots(3, 3, figsize = (18, 7))
categories = ['N', 'L', 'R', 'V', 'A', 'F', 'f', '/']
for i in range(len(categories)):
    indices_category = np.argwhere(alldata[:, -2] == i + 1)
    ax[i // 3, i % 3].plot(np.arange(275), alldata[indices_category[5], :-2][0])
    ax[i // 3, i % 3].set_title('Class: ' + str(categories[i]) + ', Number: ' + str(i + 1))
ax[2, 2].axis('off')
plt.tight_layout()
fig.savefig('ecg_data_preprocessed.jpg', dpi = 400)

# %% [markdown]
# ### Save all preprocessed data into one .csv file.

# %%
# Remove unidentified beats and save all data:
no_anno = np.where(alldata[:,-2]==0.0)[0]
print(no_anno.shape)
alldata = np.delete(alldata, no_anno,0)
print(alldata.shape)

with open('./all_data.csv', "wb") as fin:
    np.savetxt(fin, alldata, delimiter=",", fmt='%f')
# Out:
# (65346,)
# (149768, 277)

# %%
files = extract_data()
i = 0

good_beats =['N','L','R','B','A','a','J','S','V','r',
             'F','e','j','n','E','/','f','Q','?']
list_anns = []

for i in range(len(files)):
    datfile = files[i]
    
    if path.exists(datfile+".hea"):
        record = wf.rdsamp(datfile)
        ann = wf.rdann(datfile, 'atr')
        list_anns.extend(ann.symbol)

dict_anns = {}

for i in list_anns:
    dict_anns[i] = dict_anns.get(i,0)+1
    
dict_anns = {k:v for k,v in dict_anns.items() if k in good_beats}

print(dict_anns.values())

fig = plt.figure(figsize=(12,6))

xlocs, xlabs = plt.xticks()
barplt = plt.bar(list(dict_anns.keys()),dict_anns.values(),width = .6)
xlocs = [j for j in dict_anns.keys()]
ylabs = [j for j in dict_anns.values()]

plt.title('Annotation Distribution for all Classes in the Dataset')
plt.xlabel('Annotations')
plt.ylabel('Counts')

for bar in barplt:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval+1000, yval)
    
plt.show()
fig.savefig('ecg_data_beats_per_class.jpg', dpi = 400)
# Out:
# dict_values([75052, 2546, 7130, 33, 7028, 982, 803, 229, 8075, 150, 83, 7259, 106, 2, 16])
